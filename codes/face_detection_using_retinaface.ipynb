# %% [markdown]
# ## **RetinaFace-MobileNetV1**

# %% [markdown]
# ### **Import Required Library**

# %%
import cv2
import time
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### **Install DSFD-Pytorch-Interface**

# %%
# !pip install git+https://github.com/hukkelas/DSFD-Pytorch-Inference.git

# %% [markdown]
# #### **Import face_detector**

# %%
import face_detection

# %% [markdown]
# #### **Check the supported Models**

# %%
print(face_detection.available_detectors)

# %% [markdown]
# #### **Initialize the REtinaFace MobileNetV1 Model**

# %%
detector = face_detection.build_detector("RetinaNetMobileNetV1", confidence_threshold=.5, nms_iou_threshold=.3)

# %%
# Read image
image_path = "test_2.jpg"
img = cv2.imread(image_path)

# Save time
t0 = time.time()

# Getting the detections
detections = detector.detect(img)

# Calculate inference time
inf_time = round(time.time() - t0, 3)

# Print results
print(f"Detections: {detections}")
print(f"Inference time: {inf_time}s")

# %%
# Draw detections
if len(detections) > 0:
    for detection in detections:
        # Converting predicted and ground truth bounding boxes to required format
        pred_bbox = detection

        pred_bbox[2] = pred_bbox[2] - pred_bbox[0]
        pred_bbox[3] = pred_bbox[3] - pred_bbox[1]

        pred_bbox = [int(i) for i in pred_bbox[:4]]

        cv2.rectangle(img,pred_bbox,(0,255,0),1)

# Write inference time
img = cv2.putText(img, f"Inf Time: {inf_time}s", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 1, cv2.LINE_AA)
     

# Display image
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
# Read image
image_path = "test.jpg"
img = cv2.imread(image_path)

# Save time
t0 = time.time()

# Getting the detections
detections = detector.detect(img)

# Calculate inference time
inf_time = round(time.time() - t0, 3)

# Print results
print(f"Detections: {detections}")
print(f"Inference time: {inf_time}s")

# %%
# Draw detections
if len(detections) > 0:
    for detection in detections:
        # Converting predicted and ground truth bounding boxes to required format
        pred_bbox = detection

        pred_bbox[2] = pred_bbox[2] - pred_bbox[0]
        pred_bbox[3] = pred_bbox[3] - pred_bbox[1]

        pred_bbox = [int(i) for i in pred_bbox[:4]]

        cv2.rectangle(img,pred_bbox,(0,255,0),5)

# Write inference time
img = cv2.putText(img, f"Inf Time: {inf_time}s", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 1, cv2.LINE_AA)
     

# Display image
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# ## **RetinaFace-ResNet50**

# %%
detector = face_detection.build_detector("RetinaNetResNet50", confidence_threshold=.5, nms_iou_threshold=.3)
# Out:
# /home/mdrafsunsheikh/Desktop/surveillance/env/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/mdrafsunsheikh/Desktop/surveillance/env/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# Read image
image_path = "test_3.jpg"
img = cv2.imread(image_path)

# Save time
t0 = time.time()

# Getting the detections
detections = detector.detect(img)

# Calculate inference time
inf_time = round(time.time() - t0, 3)

# Print results
print(f"Detections: {detections}")
print(f"Inference time: {inf_time}s")
# Out:
# /home/mdrafsunsheikh/Desktop/surveillance/env/lib/python3.12/site-packages/face_detection/retinaface/detect.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16_inference):
# Detections: [[881.45294    325.76227    992.9884     460.70694      0.9994623 ]
#  [740.1027     650.57684    811.0729     748.8871       0.9993297 ]
#  [567.82526    191.22658    626.3964     267.25623      0.9993061 ]
#  [388.37247    640.34247    479.816      747.6654       0.9992612 ]
#  [690.49164     22.112896   780.91693    148.5834       0.99923134]
#  [ 43.762146   361.4598     108.25335    437.39722      0.99922264]
#  [905.7433     202.39369    976.9249     296.5583       0.99897146]
#  [241.19458    628.4326     323.86157    747.09265      0.9989089 ]
#  [394.8473     356.48517    463.59192    436.33975      0.99885786]
#  [ 50.64589    195.23875    125.58441    295.29736      0.9988386 ]
#  [551.9884     484.88434    631.9296     597.21674      0.9988305 ]
#  [546.60724    635.8588     629.3942     749.59875      0.9987399 ]
#  [ 69.231415    56.308228   135.52242    146.05444      0.99872416]
#  [722.0601     502.97125    799.82135    599.1781       0.99871206]
#  [211.5487     498.78748    280.7954     593.84656      0.99870944]
#  [235.02847     47.485775   292.80634    126.658066     0.99870217]
#  [ 31.749245   493.1615     102.16898    582.7164       0.99866056]
#  [560.56354    352.1969     625.3972     442.84595      0.9984665 ]
#  [ 47.468925   656.8782     123.53061    749.958        0.9983885 ]
#  [895.94336     49.39414    966.7991     149.40265      0.9982046 ]
#  [883.39856    630.9917     954.6915     735.0461       0.99792165]
#  [392.8632      45.6423     464.80252    145.4782       0.99775106]
#  [222.49103    353.69952    294.29874    448.52267      0.9975541 ]
#  [221.78398    182.5473     291.14203    276.70956      0.99752873]
#  [552.31165     44.27448    626.0347     140.9372       0.996707  ]
#  [392.8706     483.0889     469.4201     586.9969       0.9965391 ]
#  [404.5925     195.07407    476.45935    284.8646       0.9964714 ]
#  [728.33014    340.20056    803.96454    447.1167       0.9960961 ]
#  [722.9566     197.50455    797.5687     296.26984      0.99604356]
#  [884.77625    490.18066    969.9689     586.41455      0.9948565 ]]
# Inference time: 3.739s

# %%
# Draw detections
if len(detections) > 0:
    for detection in detections:
        # Converting predicted and ground truth bounding boxes to required format
        pred_bbox = detection

        pred_bbox[2] = pred_bbox[2] - pred_bbox[0]
        pred_bbox[3] = pred_bbox[3] - pred_bbox[1]

        pred_bbox = [int(i) for i in pred_bbox[:4]]

        cv2.rectangle(img,pred_bbox,(0,255,0),3)

# Write inference time
img = cv2.putText(img, f"Inf Time: {inf_time}s", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 3, cv2.LINE_AA)
     

# Display image
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
import face_detection
import cv2
import time
import matplotlib.pyplot as plt

# Build the face detector
detector = face_detection.build_detector("RetinaNetResNet50", confidence_threshold=.5, nms_iou_threshold=.3)

# Read image
image_path = "test_3.jpg"
img = cv2.imread(image_path)

# Save time
t0 = time.time()

# Getting the detections
detections = detector.detect(img)

# Calculate inference time
inf_time = round(time.time() - t0, 3)

# Print results
print(f"Detections: {detections}")
print(f"Inference time: {inf_time}s")

# Counter for saved face images
face_counter = 0

# Draw detections and save individual faces
if len(detections) > 0:
    for detection in detections:
        # Extract bounding box coordinates
        x_min, y_min, x_max, y_max = detection[:4]
        
        # Convert to integer values
        x_min, y_min, x_max, y_max = int(x_min), int(y_min), int(x_max), int(y_max)
        
        # Crop the face from the image
        face = img[y_min:y_max, x_min:x_max]
        
        # Save the face as a separate image
        face_filename = f"face_{face_counter}.jpg"
        cv2.imwrite(face_filename, face)
        
        # Increment the counter
        face_counter += 1
        
        # Optionally display each face
        plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
        plt.title(f"Face {face_counter}")
        plt.show()
        
        # Draw bounding box on the original image
        cv2.rectangle(img, (x_min, y_min), (x_max, y_max), (0, 255, 0), 3)

# Write inference time on the image
img = cv2.putText(img, f"Inf Time: {inf_time}s", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 3, cv2.LINE_AA)

# Convert the image from BGR to RGB for displaying with matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image with bounding boxes
plt.imshow(img_rgb)
plt.title("Detected Faces")
plt.show()
# Out:
# Detections: [[881.45294    325.76227    992.9884     460.70694      0.9994623 ]
#  [740.1027     650.57684    811.0729     748.8871       0.9993297 ]
#  [567.82526    191.22658    626.3964     267.25623      0.9993061 ]
#  [388.37247    640.34247    479.816      747.6654       0.9992612 ]
#  [690.49164     22.112896   780.91693    148.5834       0.99923134]
#  [ 43.762146   361.4598     108.25335    437.39722      0.99922264]
#  [905.7433     202.39369    976.9249     296.5583       0.99897146]
#  [241.19458    628.4326     323.86157    747.09265      0.9989089 ]
#  [394.8473     356.48517    463.59192    436.33975      0.99885786]
#  [ 50.64589    195.23875    125.58441    295.29736      0.9988386 ]
#  [551.9884     484.88434    631.9296     597.21674      0.9988305 ]
#  [546.60724    635.8588     629.3942     749.59875      0.9987399 ]
#  [ 69.231415    56.308228   135.52242    146.05444      0.99872416]
#  [722.0601     502.97125    799.82135    599.1781       0.99871206]
#  [211.5487     498.78748    280.7954     593.84656      0.99870944]
#  [235.02847     47.485775   292.80634    126.658066     0.99870217]
#  [ 31.749245   493.1615     102.16898    582.7164       0.99866056]
#  [560.56354    352.1969     625.3972     442.84595      0.9984665 ]
#  [ 47.468925   656.8782     123.53061    749.958        0.9983885 ]
#  [895.94336     49.39414    966.7991     149.40265      0.9982046 ]
#  [883.39856    630.9917     954.6915     735.0461       0.99792165]
#  [392.8632      45.6423     464.80252    145.4782       0.99775106]
#  [222.49103    353.69952    294.29874    448.52267      0.9975541 ]
#  [221.78398    182.5473     291.14203    276.70956      0.99752873]
#  [552.31165     44.27448    626.0347     140.9372       0.996707  ]
#  [392.8706     483.0889     469.4201     586.9969       0.9965391 ]
#  [404.5925     195.07407    476.45935    284.8646       0.9964714 ]
#  [728.33014    340.20056    803.96454    447.1167       0.9960961 ]
#  [722.9566     197.50455    797.5687     296.26984      0.99604356]
#  [884.77625    490.18066    969.9689     586.41455      0.9948565 ]]
# Inference time: 1.048s

# %%
# Read image
image_path = "test.jpg"
img = cv2.imread(image_path)

# Save time
t0 = time.time()

# Getting the detections
detections = detector.detect(img)

# Calculate inference time
inf_time = round(time.time() - t0, 3)

# Print results
print(f"Detections: {detections}")
print(f"Inference time: {inf_time}s")

# %%
# Draw detections
if len(detections) > 0:
    for detection in detections:
        # Converting predicted and ground truth bounding boxes to required format
        pred_bbox = detection

        pred_bbox[2] = pred_bbox[2] - pred_bbox[0]
        pred_bbox[3] = pred_bbox[3] - pred_bbox[1]

        pred_bbox = [int(i) for i in pred_bbox[:4]]

        cv2.rectangle(img,pred_bbox,(0,255,0),5)

# Write inference time
img = cv2.putText(img, f"Inf Time: {inf_time}s", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 3, cv2.LINE_AA)
     

# Display image
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# ## **Face Enhancement**

# %%
from cv2 import dnn_superres

# %%
# Create the SR object
sr = dnn_superres.DnnSuperResImpl_create()

# %%
# Read Image
face_image_path = 'face_29.jpg'
face_image = cv2.imread(face_image_path)

# %%
# Load the desired model
model_path = "../weights/LapSRN_x8.pb"
sr.readModel(model_path)

# %%
# Set the desired model and scale to get correct pre- and post-processing
sr.setModel("lapsrn", 8)

# Upscale the image
result = sr.upsample(face_image)


# Display image
img = cv2.cvtColor(face_image,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# Display image
img = cv2.cvtColor(result,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# # Save the image
# cv2.imwrite("Monarch-butterfly-tall-l_upscaled_lapsrn.png", result)

# %%
import numpy as np

kernel = np.array([[0, -1, 0],
                   [-1, 5,-1],
                   [0, -1, 0]])
image_sharp_1 = cv2.filter2D(src=result, ddepth=-1, kernel=kernel)

cv2.imshow('Sharpened Result image face', image_sharp_1)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/mdrafsunsheikh/Desktop/surveillance/env/lib/python3.12/site-packages/cv2/qt/plugins"

# %% [markdown]
# ## **Face Recognition**

# %%
#!pip install deepface
from deepface import DeepFace
obj = DeepFace.verify(image_sharp_1, "test_5.png", model_name = "ArcFace", detector_backend = "retinaface")
print(obj["verified"])
# Out:
# True

# %%
obj
# Out:
# {'verified': True,
#  'distance': 0.4821255796344237,
#  'threshold': 0.68,
#  'model': 'ArcFace',
#  'detector_backend': 'retinaface',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 0,
#    'y': 0,
#    'w': 679,
#    'h': 767,
#    'left_eye': (381, 229),
#    'right_eye': (114, 361)},
#   'img2': {'x': 356,
#    'y': 91,
#    'w': 169,
#    'h': 245,
#    'left_eye': (480, 188),
#    'right_eye': (402, 190)}},
#  'time': 19.17}
